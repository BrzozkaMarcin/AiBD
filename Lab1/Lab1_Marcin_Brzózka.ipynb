# %% [markdown]
# Marcin Brzózka
# nr albumu 405499
# grupa 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ***Zadanie 3***
# Zdefiniuj poniższą funkcję i sporządź jej wykres dla argumentów z danego przedziału:
#        ***f(x)=x^2+5***
# 1.	x>−1 oraz x<1
# 2.	x>−6 oraz x<6
# 3.	x>0 oraz x<5
#
# Wspierając się dokumentacją Matplotlib. Dodaj do wykresu etykiety osi, tytuły wykresów i legendy.
#
# Wskazówki: Deklaracja funkcji w Python.
#
# W Pythonie bloki kodu (w tym również funkcje) są wyróżniane za pomocą wcięć. Do wizualizacji wyników w Pythonie używa się pakietu Matplotlib.
#
# W pliku mają być zawarte: imię, nazwisko, opis wykonywanego ćwiczenia - formatowanie markdown w poszczególnych komórkach.

# %%
def y(x:np.array) -> np.array:
    y = np.array([])
    y = x ** 2 + 5
    return y

x1 = np.linspace(-1, 1, 50)
x2 = np.linspace(-6, 6, 50)
x3 = np.linspace(-0, 5, 100)

plt.plot(x1, y(x1), label ='x∈<−1,1>', color='black')
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.legend()
plt.title('y = x^2 + 5')
plt.xlabel('x1')
plt.ylabel('y')
plt.show()

plt.plot(x2, y(x2), label ='x∈<−6,6>', color='blue')
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.legend()
plt.title('y = x^2 + 5')
plt.xlabel('x2')
plt.ylabel('y')
plt.show()

plt.plot(x3, y(x3), label ='x∈<0,5>', color='green')
plt.grid(color='green', linestyle='--', linewidth=0.5)
plt.legend()
plt.title('y = x^2 + 5')
plt.xlabel('x3')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ***Zadanie 4***
# Utwórz dataframe, w którym kolumny mają nazwy: name, surname, age, sex. Uzupełnij pięcioma dowolnymi rekordami oraz wyświetl informacje o danych pandas .info(), opis danych pandas .describe(), wyświetl pierwsze trzy rekordy pandas .head().

# %%
names = ['Adam', 'Tomasz', 'Kasia', 'Jan', 'Basia']
surnames = ['Kot', 'Filon', 'Fil', 'Domek', 'Kil']
ages = [18, 28, 24, 21, 30]
sexs = ['male', 'male', 'female', 'male', 'female']

d = {'Name': names, 'Surname': surnames, 'Age' : ages, 'Sex' : sexs}
df = pd.DataFrame(data=d)
df.info()
print()
print(df.describe())
print()
print(df.head(3))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   Surname  5 non-null      object
#  2   Age      5 non-null      int64
#  3   Sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes
#
#             Age
# count   5.00000
# mean   24.20000
# std     4.91935
# min    18.00000
# 25%    21.00000
# 50%    24.00000
# 75%    28.00000
# max    30.00000
#
#      Name Surname  Age     Sex
# 0    Adam     Kot   18    male
# 1  Tomasz   Filon   28    male
# 2   Kasia     Fil   24  female
